# %%
import pandas as pd

# %%
data = pd.read_csv("https://raw.githubusercontent.com/jamc88/Analisis-datos-atmosfericos/refs/heads/main/datos/rama_2023_05.csv")
#data=pd.read_csv("https://raw.githubusercontent.com/jam88/Analisis-datos-atmosfericos/refs/heads/main/datos/rama_2023_05.csv")

# %%
pip install scikit-learn
# Out:
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.10/dist-packages (1.5.2)
# Requirement already satisfied: numpy>=1.19.5 in /usr/local/lib/python3.10/dist-packages (from scikit-learn) (1.26.4)
# Requirement already satisfied: scipy>=1.6.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn) (1.13.1)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn) (3.5.0)

# %%
from posixpath import split
X=data[['CO','NOX']]
y=data['PM10']
split_index=int(len(data)*0.8)

# %%
split_index= int(len(data)*0.8)

# %%
X_train=X.iloc[:split_index]
X_test=X.iloc[split_index:]
y_train=y.iloc[:split_index]
y_test=y.iloc[split_index:]

# %%
from sklearn.linear_model import LinearRegression

# %%
model=LinearRegression()
model.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
y_pred=model.predict(X_test)

# %%
coeficientes=pd.DataFrame({'Variable':X.columns,'Coeficientes':model.coef_})

# %%
print(f"Intercepto:{model.intercept_}")
# Out:
# Intercepto:15.394050316557077

# %%
#from sklearn.metrics import mean_squared_error, r2_score(y_test,y_pred, squared=False)

from sklearn.metrics import mean_squared_error, r2_score, mean_absolute_error

r2=r2_score(y_test, y_pred)

# %%
r2
# Out:
# 0.4051483156923722

# %%
import matplotlib.pyplot as plt

# %%
residuos= y_test- y_pred
rmse=mean_squared_error(y_test, y_pred, squared=False)
rmse
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_regression.py:492: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(
# 11.015555045398493

# %%
mae=mean_absolute_error(y_test, y_pred)
mae
# Out:
# 8.77187127970108

# %%
plt.hist(residuos,bins=15,color="gray",alpha=0.7)
plt.title('Distribucion de residuos')
plt.xlabel('Residuos')
plt.ylabel('Frecuencia')
# Out:
# Text(0, 0.5, 'Frecuencia')

# %%
plt.figure(figsize=(12,6))
plt.plot(data.iloc[split_index:]['fecha'], y_test, linestyle='--', color='green')
plt.plot(data.iloc[split_index:]['fecha'], y_pred, linestyle='-', color='red')

# %%
from sklearn.model_selection import train_test_split

from sklearn.ensemble import RandomForestRegressor

# %%
data=data.sort_values(by='fecha')

split_index=int(len(data)*0.8)

X_train=X.iloc[:split_index]
X_test=X.iloc[split_index:]

y_train=y.iloc[:split_index]
y_test=y.iloc[split_index:]

# %%
rf_model=RandomForestRegressor(n_estimators=100, max_depth=10, random_state=42)
rf_model.fit(X_train,y_train)

#rf_model=RandomForestRegressor(n_estimators=100, max_depth=5, random_state=42)
#rf_model.fit(X_train, y_train)
# Out:
# RandomForestRegressor(max_depth=10, random_state=42)

# %%
y_pred=rf_model.predict(X_test)
y_pred
# Out:
# array([39.46441521, 36.63846167, 27.44398214, 32.58887259, 46.11693557,
#        44.62046955, 44.66659135, 43.76436751, 34.94115363, 27.79391997,
#        25.34940798, 28.63291421, 32.41834746, 30.32589561, 35.11658817,
#        34.37962094, 30.52086994, 41.64941773, 45.41549131, 53.00842396,
#        50.60567541, 37.99424308, 24.96528216, 23.56251333, 37.07106115,
#        48.06791282, 42.48438188, 27.53715252, 32.24709474, 35.06690752,
#        32.50438981, 51.08592562, 52.37098392, 49.12741217, 45.37906085,
#        45.48388693, 50.15816899, 35.45936251, 42.25623838, 45.63201126,
#        50.55676391, 53.8830634 , 48.80895999, 47.51397743, 31.79681744,
#        49.08539915, 47.24063279, 52.4247101 , 50.99995815, 46.49251729,
#        32.44108757, 33.0556775 , 36.34963207, 51.52917689, 52.45122354,
#        50.69905611, 35.66069435, 40.08205854, 34.04262761, 31.8144628 ,
#        46.40360934, 57.50666229, 52.3370138 , 49.18755993, 58.71034948,
#        41.79680301, 43.25360652, 37.90236157, 46.18491444, 44.96662586,
#        46.92317578, 52.43848167, 46.34956998, 34.04603353, 43.43449921,
#        32.40665401, 45.87087608, 53.35887904, 51.02616562, 44.50745452,
#        53.47845358, 42.5842112 , 43.49582614, 50.86595965, 54.88252671,
#        50.96440542, 35.79057287, 52.44000894, 45.91370086, 57.61217131,
#        58.24044278, 63.7586206 , 67.49842425, 58.60300389, 52.26483146,
#        35.28543168, 28.48950168, 50.41971974, 54.40402302, 52.40491171,
#        54.15278923, 50.10678304, 43.90327818, 56.49056729, 56.71688412,
#        44.21549336, 53.78983781, 32.01561047, 39.98637384, 36.69155516,
#        37.44150594, 57.87902106, 49.62951067, 33.96363431, 39.17010167,
#        32.70837266, 32.18766006, 46.2417544 , 46.26989903, 43.24909805,
#        52.45768665, 36.32252007, 37.62636449, 30.6516594 , 46.04613419,
#        40.00388077, 28.60279784, 45.78236442, 44.9240497 , 35.3990666 ,
#        36.18837701, 39.18864179, 49.94737323, 46.1736752 , 46.74563255,
#        50.03127491, 49.30086964, 35.26667924, 50.74290192, 50.98169759,
#        53.65350714, 54.45028223, 54.19534507, 53.92183552, 36.78243772,
#        45.83796714, 48.60201407, 44.7238176 , 44.681255  , 50.00212919,
#        28.47168773, 22.87366771, 32.05676609, 47.26772465, 48.58498807,
#        45.8481774 , 42.94552702, 46.13563243, 35.42542741, 44.42840025,
#        48.75932939, 41.62673242, 44.02030996, 54.60336868, 41.18296113,
#        31.64278844, 42.05987221, 40.20087329, 42.71095735, 27.15050937,
#        37.42657137, 24.41848491, 28.91203811, 35.7504699 , 30.87172707,
#        32.39852546, 38.99186731, 43.70967379, 49.1850599 , 27.73004266,
#        27.00358776, 34.54138399, 41.93066965, 40.74329558, 53.56527086,
#        33.85232704, 34.20225477, 33.51772403, 32.4827298 , 52.64037335,
#        46.59981417, 42.15204957, 45.51691595, 33.1968004 , 31.27344067,
#        33.15143388, 34.33054996, 44.55471389, 48.4073743 , 44.80058612,
#        31.94727689, 35.94733687, 50.01611404, 43.86957901, 44.10228706,
#        46.48745291, 43.88491086, 34.33243643, 36.64652129, 38.41348672,
#        43.28644437, 28.26658566, 39.92918387, 34.73942113, 27.52740584,
#        33.74948835, 47.72252476, 35.39685216, 32.87537348, 32.66731344,
#        30.48940439, 27.48959464, 34.3571974 , 44.90125004, 32.96570218])

# %%
plt.figure(figsize=(12,6))
plt.plot(data.iloc[split_index:]['fecha'],y_test,linestyle='--',color='green')
plt.plot(data.iloc[split_index:]['fecha'],y_pred,linestyle='-',color='red')

# %% [markdown]
# sdr
# seleccion de caracteristicas, variables temporales
# Support vector regressor
#
# ---

# %%
plt.figure(figsize)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-33-e987b20d74f9> in <cell line: 1>()
# ----> 1 plt.figure(figsize)
#
# NameError: name 'figsize' is not defined
